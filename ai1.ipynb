# %% [markdown]
# <h1> CS4618 Assignment - Spam Filter</h1>

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
import glob
import re

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import SGDClassifier

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer



class DataFrameSelector(BaseEstimator,TransformerMixin):
    def __init__(self, attribute_names, dtype = None):
        self.attribute_names = attribute_names
        self.dtype = dtype
    def fit(self, X, y = None):
        return self
    def transform(self, X):
        X_selected = X[self.attribute_names]
        if self.dtype:
            return X_selected.astype(self.dtype).values
        return X_selected.values
    
class FeatureBinarizer(BaseEstimator, TransformerMixin):
    def __init__(self, features_values):
        self.features_values = features_values
        self.num_features = len(features_values)
        self.labelencodings = [LabelEncoder().fit(feature_values) for feature_values in features_values]
        self.onehotencoder = OneHotEncoder(sparse=False,n_values=[len(feature_values) for feature_values in features_values])
        self.last_indexes = np.cumsum([len(feature_values) - 1 for feature_values in self.features_values])
    def fit(self, X, y=None):
        for i in range(0, self.num_features):
            X[:, i] = self.labelencodings[i].transform(X[:, i])
        return self.onehotencoder.fit(X)
    def transform(self, X, y=None):
        for i in range(0, self.num_features):
            X[:, i] = self.labelencodings[i].transform(X[:, i])
        onehotencoded = self.onehotencoder.transform(X)
        return np.delete(onehotencoded, self.last_indexes, axis=1)
    def fit_transform(self, X, y=None):
        onehotencoded = self.fit(X).transform(X)
        return np.delete(onehotencoded, self.last_indexes, axis=1)
    def get_params(self, deep=True):
        return {"features_values" : self.features_values}
    def set_params(self, **parameters):
        for parameter, value in parameters.items():
            self.setattr(parameter, value)
        return self

# %% [markdown]
# <h1>1. Reading the mails</h1>
# <p>The method takes in a <b>path</b>('spam' or 'ham') and returns a <b>pandas DataFrame object</b>.</p>
# <p>The pandas DataFrame object has as columns the <b>content</b> and the <b>type</b> of a mail.The content is the text of the mail as it is and the type is determined from the path, which will be either spam or ham</p>

# %%
def readMails(path):
    mails = pd.DataFrame(dtype=object, columns=['content','type'])
    files = glob.glob('./' + path + '/*.txt')
    for file in files:
        with open(file) as f:
            text = f.read()
            mails = mails.append({'content':text, 'type':path}, ignore_index=True)
    return mails

# %%
spams = readMails('spam')
hams = readMails('ham')

# %%
mails = spams.append(hams)

# %% [markdown]
# <h1>2. Explore the mails</h1>

# %%
(rows, cols) = mails.shape
(rows, cols)
# Out:
# (2898, 2)

# %%
mails.describe(include='all')
# Out:
#                                                   content  type
# count                                                2898  2898
# unique                                               2898     2
# top     From fork-admin@xent.com  Mon Jul 22 18:13:54 ...   ham
# freq                                                    1  1650

# %%
hams_count = (mails['type'] == 'ham').sum();
spams_count = (mails['type'] == 'spam').sum();
print('Total number of hams = ', hams_count, '(',hams_count / rows * 100,'%)')
print('Total number of spam = ', spams_count, '(',spams_count / rows * 100,'%)')
# Out:
# Total number of hams =  1650 ( 56.9358178054 %)
# Total number of spam =  1248 ( 43.0641821946 %)

# %% [markdown]
# <p> The emails contain:</p>
# <ul>
#     <li><b>Header and Body</b></li>
#     <li><b>Uppercase and lowercas words</b></li>
#     <li><b>HTML tags</b>:eg < font color="blue" > </li>
#     <li><b>Numbers</b>:eg 123 300,000</li>
#     <li><b>Money amount</b>:eg $15.00</li>
#     <li><b>Underscores</b>: eg _______ </li>
# </ul>

# %% [markdown]
# <h1>3. CountVectorizer & TFIDF </h1>

# %% [markdown]
# <p><b>3.1 Uppercase words</b><p>
# <p>The spam mails usually contain multiple uppercase word (eg. PROTECT YOUR LOVED ONES AND YOURSELF). It could be useful to distinguish between lowercase and uppercase words in case of a spam filter. Decision was to <b>set lowercase to False</b> in both CountVectorizer and TFIDF.</p>
#
# <p><b>3.2 Stop-words</b></p>
# <p>Stop-words are very frequent in both spam and ham emails. The decision was to discard them, as they do not add anything to the content, so we <b>set stop_words to english</b></p>
#
# <p><b>3.3 HTML tags</b></p>
# <p>HTML tags can be useful in detecting a spam. An HTML tag can mean something being very colorful by setting the font, color and size of the text. Usually, spams contain a lot of html tags, bigger fonts. it would be useful to have an <b>HTML tag as a feature</b> after running the pipeline. The regular expression below defines an HTML tag, which is a '<' followed by 1 or more characters and a '>' at the end. This expression will be used when making the tokenizer.

# %%
html = r'\<[a-z]{1,}.*?\>' #'<' + one/more letters + arbitrary sequence of characters + ending in '>'

# %% [markdown]
# <p><b>3.4 Additional features</b></p>
# <p>In multiple spams appears money (eg $12.50), numbers and underscores for filling out a form (eg. ___ ). This could also be distinct features, as they add to the content and their presence could be a clue whether the mail is a spam of a ham. The regular expressions below define a pattern for the money, underscores and alphanumeric strings. The <b>pattern</b> combines all 4 of them into a single one.</p>

# %%
money = r'\$[0-9]{1,}?\.?[0-9]{1,}' #$ + one/more digits + .(optionally) + one/more digits(optionally)
alpha = r'[a-zA-Z0-9]{2,}' #two or more lowercase,uppercase letters and/or numbers
underscores = r'\_{1,}' #one or more consecutive underscores
pattern = re.compile(alpha + '|' + money + '|' + html + '|' + underscores) #combining them

# %% [markdown]
# <p><b>3.5 Builing the tokenizer </b></p>
# <p><b>tokenize</b> method takes in a <b>text</b>, uses the regular expression <b>pattern</b> and a list <b>discard_chars</b>, and returns the obtained <b>tokenized list.</b><p> In the first step, the characters in the list discard_chars are removed from the text. The second step performes the tokenization, creates a list containing every single token which has the format defined by the pattern regular expression.</p>

# %%
discard_chars = '(),!.,?'

# %%
def tokenize(text):
    text = re.sub('[' + discard_chars + ']', ' ', text)
    return re.findall(pattern, text)

# %% [markdown]
# <p><b>3.5 Testing the new additions</b></p>
# <p>Below we test the functionality of CountVectorizer using the parameters <b>stop_words</b>, <b>lowercase</b> and <b>tokenizer</b>, in case of the first 3 mails.</p>

# %%
test_pipeline = Pipeline([
    ("selector", DataFrameSelector('content')),
    ("vectorizer", TfidfVectorizer(stop_words='english', 
                                   lowercase=False,
                                   tokenizer=tokenize))
])
sample = mails[0:3]
test_pipeline.fit(sample)
X = test_pipeline.transform(sample)
test_pipeline.named_steps["vectorizer"].get_feature_names()
# Out:
# ['$10',
#  '$100',
#  '$20',
#  '$250',
#  '$29',
#  '$49',
#  '$499',
#  '$5844',
#  '$715',
#  '$795',
#  '00',
#  '000',
#  '000000',
#  '0000EE',
#  '0100',
#  '0102',
#  '01C20036',
#  '025e46c53a6a',
#  '04',
#  '0400',
#  '046G9H4890',
#  '05',
#  '0500',
#  '05602',
#  '0700',
#  '08',
#  '0899',
#  '09',
#  '0E47D440E7',
#  '10',
#  '100',
#  '101',
#  '1027zbAU4',
#  '103',
#  '10391',
#  '105',
#  '11',
#  '1100',
#  '12',
#  '127',
#  '13',
#  '130',
#  '14',
#  '140',
#  '1493',
#  '15',
#  '1533',
#  '1600',
#  '161',
#  '168',
#  '17',
#  '18',
#  '180',
#  '19',
#  '192',
#  '193',
#  '1999',
#  '20',
#  '200',
#  '2002',
#  '2003marketing',
#  '21',
#  '212',
#  '212580644306344345450286',
#  '213',
#  '2195',
#  '22',
#  '221',
#  '222',
#  '23',
#  '24',
#  '242',
#  '25',
#  '253',
#  '254sWzM249l35',
#  '28',
#  '31',
#  '32',
#  '33CCFF',
#  '35',
#  '36',
#  '38',
#  '39',
#  '3D',
#  '3Dwindow',
#  '3db56bb7',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '47',
#  '48',
#  '4NAK2L08LHSQ274W7VU',
#  '50',
#  '500',
#  '52f',
#  '55',
#  '551A8B',
#  '600',
#  '64',
#  '68',
#  '731',
#  '744CWZI4637aGiQ5',
#  '760',
#  '77',
#  '7785',
#  '800',
#  '8424',
#  '86',
#  '8859',
#  '8bit',
#  '92003',
#  '98',
#  '99',
#  '9RN8VV8Y',
#  '<a href="http://www askthelawyers com/apps/remove asp email=webmaster@efi ie">',
#  '<b>',
#  '<body bgcolor="#FFFFFF" text="#000000" link="#990033" vlink="#000066" alink="#FF0000" leftmargin="0" topmargin="0" marginwidth="0" marginheight="0">',
#  '<br>',
#  '<center>',
#  '<font color="#000000">',
#  '<font color="#333399" size="1">',
#  '<font color="#333399">',
#  '<font color="#990000">',
#  '<font color="#990033">',
#  '<font color="#FF0000">',
#  '<font color="#FFCC99">',
#  '<font color="#FFFFFF">',
#  '<font color=3D"#FF0000">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif" color="#333399" size="2">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif" color="#333399">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif" size="2" color="#333399">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif" size="2">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif" size="3" color="#FFFFFF">',
#  '<font face="Verdana  Arial  Helvetica  sans-serif">',
#  '<font face=3D"Arial Helvetica">',
#  '<font size="1" face="Arial  Helvetica  sans-serif" color="#990000">',
#  '<font size="1">',
#  '<font size="2" color="#000000" face="Verdana  Arial  Helvetica  sans-serif">',
#  '<font size="2" face="Arial  Helvetica  sans-serif" color="#990000">',
#  '<font size="2" face="Verdana  Arial  Helvetica  sans-serif">',
#  '<font size="2">',
#  '<font size="3">',
#  '<font size="4" face="Verdana  Arial  Helvetica  sans-serif" color="#333399">',
#  '<font size="4">',
#  '<font size=3D+2>',
#  '<font size=3D+3>',
#  '<font size=3D+4>',
#  '<head>',
#  '<hr WIDTH=3D"600">',
#  '<html>',
#  '<i>',
#  '<img src="http://www askthelawyers com/email asp email=webmaster@efi ie&campaign=78" width="1" height="1">',
#  '<img src="http://www attorneyconnectionsinc com/email/bar gif" width="600" height="75">',
#  '<img src="http://www attorneyconnectionsinc com/email/logo gif" width="250" height="117">',
#  '<img src="http://www attorneyconnectionsinc com/email/pic jpg" width="600" height="126">',
#  '<img src="http://www attorneyconnectionsinc com/email/top gif" width="600" height="39">',
#  '<jennifer@attorneyconnectionsinc com>',
#  '<jm@jmason org>',
#  '<jm@localhost>',
#  '<jm@netnoteinc com>',
#  '<martenb@aol com>',
#  '<meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">',
#  '<p align="center">',
#  '<p>',
#  '<script>',
#  '<table BORDER CELLSPACING=3D0 CELLPADDING=3D0 WIDTH=3D"600" >',
#  '<table width="100%" border="0" cellspacing="0" cellpadding="3">',
#  '<table width="100%" border="0" cellspacing="0" cellpadding="5">',
#  '<table width="100%" border="1" cellspacing="0" cellpadding="4" bordercolor="#000000">',
#  '<table width="100%" border="1" height="71" cellpadding="1" cellspacing="0" bordercolor="#333399">',
#  '<table width="600" border="0" cellspacing="0" cellpadding="0">',
#  '<table width="600" border="0" cellspacing="0" cellpadding="10">',
#  '<table width="600" border="0" cellspacing="0" cellpadding="5">',
#  '<td align="center" valign="middle" bgcolor="#000099">',
#  '<td align="center" valign="top">',
#  '<td align="left" valign="middle">',
#  '<td align="left" valign="top">',
#  '<td colspan="2" valign="middle">',
#  '<td height="10">',
#  '<td height="20">',
#  '<td valign="middle" align="center" bgcolor="#333399">',
#  '<td valign="middle" align="center">',
#  '<td valign="top" align="left">',
#  '<td width="219" height="16" valign="middle">',
#  '<td width="219" height="2" align="left" valign="middle">',
#  '<td width="219" height="3" valign="middle">',
#  '<td width="219" valign="middle" height="5">',
#  '<td width="219" valign="middle">',
#  '<td width="300" align="left" valign="top">',
#  '<td width="37" align="center" height="3" valign="middle">',
#  '<td width="37" align="center" valign="middle" height="5">',
#  '<td width="37" align="center" valign="middle">',
#  '<td width="37" height="16" align="center" valign="middle">',
#  '<td width="37" height="2" valign="middle">',
#  '<td>',
#  '<title>',
#  '<tr align="center">',
#  '<tr>',
#  '<webmaster@efi ie>',
#  '<yyyy@netnoteinc com>',
#  'A8BD08B0',
#  'A998043FA2',
#  'AD',
#  'ADDRESS',
#  'ADDRESSES',
#  'ALL',
#  'AND',
#  'ANYONE',
#  'ASCII',
#  'AWAY',
#  'Abuse',
#  'Address',
#  'Adult',
#  'After',
#  'Alabama',
#  'All',
#  'Anyone',
#  'Approval',
#  'Approved',
#  'Are',
#  'Arizona',
#  'Arkansas',
#  'As',
#  'Associations',
#  'Attorney',
#  'Audio',
#  'Authentication',
#  'Available',
#  'BULK',
#  'BULKBOOK',
#  'BUYERS',
#  'BY',
#  'Bar',
#  'BareNaked',
#  'Bat',
#  'Bias',
#  'Bonsall',
#  'Box',
#  'Brought',
#  'Bulk',
#  'Bulkbook',
#  'Business',
#  'By',
#  'CA',
#  'CAN',
#  'CASH',
#  'CELEBRITIES',
#  'CHENEYC32qU4Z5flHgS0000166e',
#  'CLICK',
#  'CRAAAAAAZY',
#  'CRAZY',
#  'CUT',
#  'California',
#  'Call',
#  'Card',
#  'Cards',
#  'Carolina',
#  'CelebX',
#  'Checks',
#  'City',
#  'Click',
#  'Com',
#  'Connections',
#  'Content',
#  'Control',
#  'Cost',
#  'Credit',
#  'Curriculum',
#  'DAY',
#  'DAYS',
#  'DELETE',
#  'Dakota',
#  'Date',
#  'Days',
#  'Delivered',
#  'Delivery',
#  'Distress',
#  'Do',
#  'Doesn',
#  'Don',
#  'Dot',
#  'Dundas',
#  'EBOOK',
#  'EDT',
#  'EMAIL',
#  'EMAILING',
#  'ENGINE',
#  'ESMTP',
#  'EVERYTHING',
#  'EXCUSE',
#  'EXPOSED',
#  'Easily',
#  'Education',
#  'Elimination',
#  'Email',
#  'Emotional',
#  'Encoding',
#  'Enriquez',
#  'Enterprises',
#  'Ethics',
#  'Ever',
#  'Expiration',
#  'Extracts',
#  'FF0000',
#  'FIGURE',
#  'FILETIME',
#  'FILTHY',
#  'FREE',
#  'FROM',
#  'FULL',
#  'Few',
#  'For',
#  'Fortune',
#  'From',
#  'Fun',
#  'GENERATOR',
#  'General',
#  'Georgia',
#  'Gets',
#  'HELO',
#  'HERE',
#  'HILTON',
#  'HOW',
#  'Hampshire',
#  'Hawaii',
#  'Held',
#  'Here',
#  'Hi',
#  'Hours',
#  'How',
#  'However',
#  'Huitt',
#  'IMAP',
#  'IMPORTANT',
#  'IMPULSE',
#  'INCLUDING',
#  'INCOME',
#  'INVESTMENT',
#  'IST',
#  'IT',
#  'Id',
#  'Idaho',
#  'If',
#  'Imagine',
#  'Importance',
#  'In',
#  'Inc',
#  'Includes',
#  'Information',
#  'Internet',
#  'Iowa',
#  'It',
#  'Jennifer',
#  'Jul',
#  'July',
#  'Jun',
#  'Just',
#  'Kansas',
#  'Keywords',
#  'Kiss',
#  'LEGAL',
#  'LIKE',
#  'LIST',
#  'LO',
#  'Legal',
#  'Limited',
#  'Louisiana',
#  'Love',
#  'MACROBOT',
#  'MAIL',
#  'MAILER',
#  'MAKING',
#  'MANAGER',
#  'MASS',
#  'MCLE',
#  'ME',
#  'MILLION',
#  'MIME',
#  'MONEY',
#  'MORE',
#  'Mailer',
#  'Mailing',
#  'Maine',
#  'Manage',
#  'Mastercard',
#  'Materials',
#  'Math',
#  'May',
#  'Maybe',
#  'Message',
#  'Mexico',
#  'Microsoft',
#  'Minnesota',
#  'Missouri',
#  'Mon',
#  'Montana',
#  'Montpelier',
#  'Most',
#  'Mozilla',
#  'Msmail',
#  'NEED',
#  'NO',
#  'NOTE',
#  'NOW',
#  'NT',
#  'Name',
#  'Netscape',
#  'Nevada',
#  'Never',
#  'New',
#  'NextPart',
#  'No',
#  'Normal',
#  'North',
#  'Note',
#  'Nothing',
#  'Now',
#  'Number',
#  'OF',
#  'ONE',
#  'OR',
#  'ORDER',
#  'OUT',
#  'Okay',
#  'On',
#  'Once',
#  'Oregon',
#  'Originalarrivaltime',
#  'Our',
#  'PEOPLE',
#  'PERSON',
#  'PERSONALLY',
#  'PUBLISHER',
#  'PULL',
#  'Passwords',
#  'Path',
#  'Pennsylvania',
#  'Phone',
#  'Postfix',
#  'Price',
#  'Print',
#  'Printable',
#  'Priority',
#  'Product',
#  'Products',
#  'Profession',
#  'Provides',
#  'Puffy',
#  'Quoted',
#  'RICH',
#  'RIGHT',
#  'ROBOT',
#  'ROVER',
#  'Received',
#  'Register',
#  'Remember',
#  'Reply',
#  'Return',
#  'SEARCH',
#  'SEND',
#  'SERIOUS',
#  'SEVEN',
#  'SIX',
#  'SMTP',
#  'SMTPSVC',
#  'START',
#  'STEALTH',
#  'SUCCESS',
#  'Secret',
#  'Seminars',
#  'Sender',
#  'Service',
#  'Seven',
#  'Shipping',
#  'Signature',
#  'So',
#  'Software',
#  'Some',
#  'South',
#  'Space',
#  'St',
#  'State',
#  'States',
#  'Stop',
#  'Subject',
#  'Substance',
#  'Success',
#  'THAN',
#  'THE',
#  'THOUSAND',
#  'TO',
#  'TOOLS',
#  'Takes',
#  'Teaches',
#  'Tennesee',
#  'Texas',
#  'That',
#  'The',
#  'There',
#  'This',
#  'Thu',
#  'To',
#  'Today',
#  'Transfer',
#  'Tue',
#  'Type',
#  'US',
#  'UTC',
#  'Unit',
#  'United',
#  'Used',
#  'Using',
#  'Utah',
#  'VERIFIER',
#  'VERSION',
#  'VT',
#  'Version',
#  'Very',
#  'Village',
#  'Virginia',
#  'Visa',
#  'WORLDCAST',
#  'Waikola',
#  'Warning',
#  'Washington',
#  'Wed',
#  'Well',
#  'What',
#  'Whether',
#  'Windows',
#  'Wisconsin',
#  'With',
#  'YES',
#  'YOU',
#  'YOUR',
#  'Yep',
#  'York',
#  'You',
#  'Your',
#  'ZERO',
#  'Zip',
#  '_',
#  '____________________',
#  '_________________________',
#  '___________________________',
#  '________________________________',
#  '________________________________________',
#  '__________________________________________',
#  '___________________________________________',
#  '_____________________________________________',
#  'absolutely',
#  'achieve',
#  'activities',
#  'actually',
#  'ad',
#  'ad2',
#  'added',
#  'address',
#  'addresses',
#  'adelphia',
#  'ads',
#  'advertisement',
#  'advice',
#  'air',
#  'alink',
#  'alternative',
#  'ambition',
#  'ambitious',
#  'answer',
#  'aol',
#  'ask',
#  'attorneyconnectionsinc',
#  'attorneysonlineinc',
#  'auction',
#  'automatically',
#  'available',
#  'away',
#  'bankruptcy',
#  'banner',
#  'basic',
#  'beats',
#  'best',
#  'bet',
#  'bgcolor',
#  'big',
#  'bin',
#  'blank',
#  'blur',
#  'body',
#  'bonus',
#  'books',
#  'booming',
#  'bought',
#  'boundary',
#  'boy',
#  'bubble',
#  'bucks',
#  'build',
#  'building',
#  'bulk',
#  'bulkbook',
#  'bulker',
#  'bulkexpert',
#  'bulking',
#  'bundle',
#  'burst',
#  'business',
#  'buy',
#  'c5d',
#  'c6c5',
#  'ca',
#  'called',
#  'campaign',
#  'capitalize',
#  'card',
#  'cash',
#  'cashier',
#  'celebhardcore',
#  'center',
#  'cgi',
#  'charset',
#  'check',
#  'cheney',
#  'classifieds',
#  'click',
#  'college',
#  'color',
#  'com',
#  'come',
#  'commercial',
#  'commitment',
#  'companies',
#  'company',
#  'complete',
#  'computer',
#  'connection',
#  'consultation',
#  'contacts',
#  'contains',
#  'content',
#  'convince',
#  'copy',
#  'corporate',
#  'cost',
#  'costs',
#  'countries',
#  'couple',
#  'created',
#  'credit',
#  'credits',
#  'criminal',
#  'crlsbd',
#  'crlsca',
#  'curious',
#  'daily',
#  'databases',
#  'day',
#  'days',
#  'deal',
#  'decent',
#  'delay',
#  'delivered',
#  'detailed',
#  'didn',
#  'dirty',
#  'doctype',
#  'doesn',
#  'dogma',
#  'dollars',
#  'don',
#  'dorm',
#  'dot',
#  'dream',
#  'drop',
#  'dropout',
#  'dtd',
#  'eBay',
#  'earn',
#  'easily',
#  'effort',
#  'efi',
#  'electronically',
#  'eliminate',
#  'email',
#  'emailer',
#  'emailing',
#  'emails',
#  'employment',
#  'en',
#  'engines',
#  'entertaining',
#  'entrepreneurs',
#  'exact',
#  'example',
#  'excessive',
#  'execs',
#  'executive',
#  'expense',
#  'experience',
#  'expert',
#  'extra',
#  'extract',
#  'extraordinary',
#  'extremely',
#  'eye',
#  'fact',
#  'familiarity',
#  'family',
#  'famous',
#  'fast',
#  'fax',
#  'fees',
#  'fetchmail',
#  'figure',
#  'filled',
#  'financial',
#  'focus',
#  'folks',
#  'follow',
#  'font',
#  'form',
#  'format',
#  'fraudulent',
#  'free',
#  'freedom',
#  'fresh',
#  'friendly',
#  'g4L3VZe19172',
#  'g6HD9SJ21165',
#  'g6PMLSp24140',
#  'g6PMMg402620',
#  'game',
#  'generated',
#  'generating',
#  'geniuses',
#  'getting',
#  'giving',
#  'goes',
#  'going',
#  'gold',
#  'goodbye',
#  'grasshopper',
#  'great',
#  'grind',
#  'guarantee',
#  'guessed',
#  'guide',
#  'handbook',
#  'hard',
#  'hardly',
#  'harvested',
#  'head',
#  'headers',
#  'heard',
#  'high',
#  'home',
#  'hot',
#  'hotel',
#  'hour',
#  'hours',
#  'hqaxpa',
#  'href',
#  'htm',
#  'html',
#  'http',
#  'huge',
#  'hurdle',
#  'id',
#  'include',
#  'included',
#  'income',
#  'information',
#  'informative',
#  'inserted',
#  'instruction',
#  'instructions',
#  'invest',
#  'iso',
#  'jennifer',
#  'jm',
#  'job',
#  'jump',
#  'just',
#  'know',
#  'knowledge',
#  'labs',
#  'later',
#  'laws',
#  'lawyers',
#  'lazy',
#  'learn',
#  'learning',
#  'lesbianslutbags',
#  'let',
#  'level',
#  'like',
#  'line',
#  'link',
#  'list',
#  'listed',
#  'listing',
#  'lists',
#  'little',
#  'll',
#  'load',
#  'local',
#  'localhost',
#  'look',
#  'looked',
#  'mail',
#  'mailing',
#  'make',
#  'makes',
#  'making',
#  'mandark',
#  'mania',
#  'margin',
#  'marketing',
#  'martenb',
#  'matter',
#  'mean',
#  'means',
#  'message',
#  'meta',
#  'million',
#  'minute',
#  'money',
#  'multi',
#  'multipart',
#  'nbsp',
#  'need',
#  'nerd',
#  'net',
#  'netnoteinc',
#  'newspaper',
#  'nineteen',
#  'non',
#  'number',
#  'numbers',
#  'office',
#  'old',
#  'online',
#  'open',
#  'opportunity',
#  'opposed',
#  'opt',
#  'option',
#  'order',
#  'ordering',
#  'orders',
#  'ordinary',
#  'org',
#  'outrageous',
#  'owners',
#  'package',
#  'participatory',
#  'passed',
#  'pay',
#  'paying',
#  'payment',
#  'pending',
#  'people',
#  'percentage',
#  'period',
#  'person',
#  'personal',
#  'personally',
#  'phobos',
#  'phone',
#  'places',
#  'plain',
#  'plenty',
#  'pocket',
#  'post',
#  'powerful',
#  'presentation',
#  'price',
#  'print',
#  'printable',
#  'printed',
#  'printing',
#  'probably',
#  'problem',
#  'problems',
#  'processing',
#  'product',
#  'products',
#  'profit',
#  'profitable',
#  'program',
#  'programmers',
#  'promise',
#  'protocol',
#  'public',
#  'publish',
#  'questions',
#  'quick',
#  'quickly',
#  'quit',
#  'quot',
#  'quoted',
#  'reach',
#  'reading',
#  'ready',
#  'real',
#  'reason',
#  'recieve',
#  'recieved',
#  'registration',
#  'regulations',
#  'remaining',
#  'remember',
#  'removal',
#  'remove',
#  'removed',
#  'removing',
#  'repeat',
#  'reports',
#  'request',
#  'required',
#  'resale',
#  'reservation',
#  'reserve',
#  'residents',
#  'respond',
#  'retails',
#  'revealed',
#  'review',
#  'rich',
#  'richer',
#  'right',
#  'room',
#  'routine',
#  'rudimentary',
#  'running',
#  'sale',
#  'salesmen',
#  'saw',
#  'scheme',
#  'script',
#  'search',
#  'secret',
#  'secure',
#  'sees',
#  'seized',
#  'sell',
#  'seminar',
#  'send',
#  'sending',
#  'sent',
#  'seperate',
#  'server',
#  'service',
#  'seven',
#  'seventh',
#  'share',
#  'simple',
#  'single',
#  'size',
#  'skills',
#  'slashnull',
#  'small',
#  'software',
#  'special',
#  'specific',
#  'speeds',
#  'start',
#  'started',
#  'starting',
#  'startup',
#  'step',
#  'stories',
#  'strictly',
#  'student',
#  'study',
#  'stuff',
#  'style',
#  'subjects',
#  'successful',
#  'sure',
#  'table',
#  'takes',
#  'target',
#  'td',
#  'teach',
#  'technique',
#  'techniques',
#  'technology',
#  'tell',
#  'text',
#  'thing',
#  'think',
#  'thought',
#  'thousand',
#  'thousands',
#  'time',
#  'tips',
#  'title',
#  ...]

# %% [markdown]
# <h1>4. Preparation for Classification</h1>

# %% [markdown]
# <p><b>4.1 Shuffle the dataset.</b> The emails were read inorder, ham after spam, so they are in a specific order. This can cause problems in case of K-Fold, since it does not shuffle the data by default. The code below takes care that the mails are in a random order.</p>

# %%
mails = mails.take(np.random.permutation(len(mails)))

# %% [markdown]
# <p><b>4.2 Encode the labels.</b></p> Currently, the types are either spam or ham, but this must be encoded into 0 and 1, using the LabelEncoder.

# %%
mails['type'].unique()
# Out:
# array(['ham', 'spam'], dtype=object)

# %%
y = mails['type'].values
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
y_encoded
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %% [markdown]
# <p><b>4.3 Dummy Classifier</b><p>
# <p>Dummy Classifier always predicts the most frequent class. This is a guideline for further classifiers to see if they do better than simple chance.</p>

# %%
pipeline_dummy = Pipeline([
    ("selector", DataFrameSelector('content')),
    ("vectorizer", CountVectorizer(stop_words='english', 
                                   lowercase=False,
                                   tokenizer=tokenize)),
    ("estimator", DummyClassifier(strategy = "most_frequent"))
])
np.mean(cross_val_score(pipeline_dummy, mails, y_encoded, scoring="accuracy", cv=10))
# Out:
# 0.56935926500417611

# %% [markdown]
# <h1>5 Classifiers</h1>
# <h1>5.1 Classifier #1</h1>
# <font size="4">Uses <b>CountVectorizer</b> and <b>StratifiedKFold</b>.</font>
# <p>1. The content of each mail is selected by the DataFrameSelector.</p>
# <p>2. CountVectorizer is used to tokenize the mails, each token will be a feature.</p>
# <p>3. StratifiedKFold is used.
#     <ul>
#         <li> Stratification is used, as the proportion of spam and ham in a fold must be the same as the proportion of spam and ham in total to make it fair and not rely on luck</li>
#         <li> In case of Holdout, the data used in the training set might not be representative(ie some mails contain a lot of clues that they are spam, while others can be between the two classes. Training only on mails that are obviously spam and obviously ham, and testing it on special cases would not give a good result. Because of this, I decided to use StratifiedKFold to estimate the accuracy. </li>
#         <li> 10 folds. There are 2898 emails, so is a relatively large data to work with. A fold would contain around 289 emails, which is enough. In case of a smaller dataset, it would be a problem. </li>

# %%
pipeline1 = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", CountVectorizer(stop_words='english', 
                                   lowercase=False,
                                   tokenizer=tokenize)),
    ("estimator", LogisticRegression())
])

# %% [markdown]
# <b>Accuracy:</b> around 97-98%, depends on the shuffle

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline1, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.97999045459968992

# %% [markdown]
# <b>Confusion Matrix:</b> It seems that the number of false positives and false negatives are balanced.

# %%
y_predicted_1 = cross_val_predict(pipeline1, mails, y_encoded, cv=10)
confusion_matrix(y_encoded, y_predicted_1)
# Out:
# array([[1622,   28],
#        [  30, 1218]])

# %% [markdown]
# <h1>5.2 Classifier #2</h1>
# <font size="4">Uses <b>TfidfVectorizer</b> and <b>StratifiedKFold</b>.</font>
# <p>Exactly the same parameters and evaluation as in classifier #2.</p>

# %%
pipeline2 = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", TfidfVectorizer(stop_words='english', 
                                   lowercase=False,
                                   tokenizer=tokenize)),
    ("estimator", LogisticRegression())
])

# %% [markdown]
# <b>Accuracy:</b> around 95%, depends on the shuffle, it seems that the pipeline with CountVectorizer performs slightly better.

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline2, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.95825796444338385

# %%
y_predicted_2 = cross_val_predict(pipeline2, mails, y_encoded, cv=10)
confusion_matrix(y_encoded, y_predicted_2)
# Out:
# array([[1599,   51],
#        [  70, 1178]])

# %% [markdown]
# <h1> 5.3. Classifier #3</h1>
# <font size="4">Uses <b>CountVectorizer</b> and <b>Bigrams</b>.</font>
# <p>Using character N-grams can be useful. Spam mails contain sections like: "BUY NOW!", "make more", "more money". Treating these n-grams as features might make detecting spam mails easier.</p>

# %% [markdown]
# <p>In this approach we will still keep the previous patterns(ie html tags, money and underscores), but in addition to these we will take into consideration <b>character bigrams (two consecutive words)</b>. The regular expression letters defines words of length greater than one containing only letters.</p>

# %%
letters = r'[a-zA-Z]{2,}'

# %% [markdown]
# <p>The method <b>nGramAnalyzer</b> takes the raw text, <b>finds all words defined by letters</b>, creates a list containing all the <b>consecutive words</b> separated by a whitespace, and adds to this list the html tags, money values and underscores. The <b>nGramAnalyzer_only_words</b> takes into account ONLY bigrams.</p>

# %%
def nGramAnalyzer(text):
    words = re.findall(letters, text)
    result = []
    for i in range (0, len(words)-1):
        result.append(words[i] + ' ' + words[i+1])
    pattern = re.compile(money + '|' + html + '|' + underscores)
    return result + re.findall(pattern,text)

def nGramAnalyzer_only_words(text):
    words = re.findall(letters, text)
    result = []
    for i in range (0, len(words)-1):
        result.append(words[i] + ' ' + words[i+1])
    return result

# %%
nGramAnalyzer("This, is just $30 a test __ to see that the analyzer works")
# Out:
# ['This is',
#  'is just',
#  'just test',
#  'test to',
#  'to see',
#  'see that',
#  'that the',
#  'the analyzer',
#  'analyzer works',
#  '$30',
#  '__']

# %% [markdown]
# <p>The following pipeline tests that the analyzer works and we get html tags, money, underscores and consecutive words as features. For this test, I am testing only the first 3 emails from the dataset.</p>

# %%
test_pipeline_analyzer = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", CountVectorizer(lowercase=False, analyzer=nGramAnalyzer))
])
sample = mails[0:3]
test_pipeline_analyzer.fit(sample)
X = test_pipeline_analyzer.transform(sample)
test_pipeline_analyzer.named_steps["vectorizer"].get_feature_names()
# Out:
# ['$40',
#  '<a class="url" href="http://photoshopplugins.tripod.com/wallpampered.htm">',
#  '<a class="url" href="http://www.madshrimps.com/index-e.php?action=webnews-e&l1=0&l2=30">',
#  '<a class="url" href="http://www.moviegear.com/gmgdet.htm">',
#  '<a class="url" href="http://www.yesiknow.com/lte/">',
#  '<a href="&#109;&#97;&#105;&#108;&#116;&#111;&#58;&#102;&#101;&#101;&#100;&#98;&#97;&#99;&#107;&#64;&#108;&#111;&#99;&#107;&#101;&#114;&#103;&#110;&#111;&#109;&#101;&#46;&#99;&#111;&#109;?subject=Lockergnome Site Feedback">',
#  '<a href="http://applecore.lockergnome.com/">',
#  '<a href="http://digitalmedia.lockergnome.com/">',
#  '<a href="http://lockergnome.pricegrabber.com/search_getprod.php/masterid=102088204">',
#  '<a href="http://mp3.lockergnome.com">',
#  '<a href="http://penguinshell.lockergnome.com/">',
#  '<a href="http://techspecialist.lockergnome.com/">',
#  '<a href="http://updates.lockergnome.com/">',
#  '<a href="http://webmasterweekly.lockergnome.com/">',
#  '<a href="http://windowsdaily.lockergnome.com/">',
#  '<a href="http://www.digitaldaze.com/?lg">',
#  '<a href="http://www.dnscentral.com/?lg">',
#  '<a href="http://www.gnomedex.com/">',
#  '<a href="http://www.gnometomes.com">',
#  '<a href="http://www.gnometomes.com/tome/001826.html">',
#  '<a href="http://www.gnometomes.com/tome/001829.html">',
#  '<a href="http://www.gnometomes.com/tome/001843.html">',
#  '<a href="http://www.gnometomes.com/tome/cat_audio.html">',
#  '<a href="http://www.gnometomes.com/tome/cat_macintosh.html">',
#  '<a href="http://www.kyocera-wireless.com/kysmart/kysmart_series.htm">',
#  '<a href="http://www.lockergnome.com/">',
#  '<a href="http://www.lockergnome.com/about.html">',
#  '<a href="http://www.lockergnome.com/advertise.html">',
#  '<a href="http://www.lockergnome.com/chat.html">',
#  '<a href="http://www.lockergnome.com/images/lockerlink.gif">',
#  '<a href="http://www.lockergnome.com/issues/">',
#  '<a href="http://www.lockergnome.com/issues/digitalmedia/20020710.html">',
#  '<a href="http://www.lockergnome.com/options.html">',
#  '<a href="http://www.lockergnome.com/options.html#syndicate">',
#  '<a href="http://www.lockergnome.com/privacy.html">',
#  '<a href="http://www.lockergnome.com/recommend.html">',
#  '<a href="http://www.lockergnome.com/special.html">',
#  '<a href="http://www.lockergnome.com/terms.html">',
#  '<a href="http://www.lockergnome.com/webcam.html">',
#  '<a href="http://www.lockergnome.com/windowsdaily.xml">',
#  '<a href="http://www.netmusiccountdown.com">',
#  '<a href="http://www.xteq.com/">',
#  '<a href="https://www.sandhills.com/secure/smartcomputing/cpufreetrial.asp?source=cpu237">',
#  '<a href="https://www.sandhills.com/secure/smartcomputing/cpufreetrial3.asp?source=cpu491bonus">',
#  '<a href="mailto:jake@lockergnome.com?subject=Lockergnome Digital Media Comment">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001099.html">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001104.html">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001105.html">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001106.html">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001629.html">',
#  '<a target="_blank" HREF="http://www.gnometomes.com/tome/001630.html">',
#  '<a target="_blank" href="http://www.gnomedex.com/">',
#  '<a target="_blank" href="http://www.gnometomes.com/tome/000623.html">',
#  '<a target="_blank" href="http://www.gnometomes.com/tome/000625.html">',
#  '<a target="_blank" href="http://www.gnometomes.com/tome/000626.html">',
#  '<a target="_blank" href="http://www.gnometomes.com/tome/000627.html">',
#  '<a target="_blank" href="http://www.gnometomes.com/tome/000628.html">',
#  '<a target="_blank" title="Capture TEXT seen in folder trees, file lists, database reports, dialog boxes, menus, status lines, including areas that you could not highlight with your mouse. (Chris cannot live without it!;)" href="http://www.structurise.com/kleptomania">',
#  '<a target="_blank" title="Choosing color combinations for the web is a careful balance between a scheme designed to draw attention; while being respectful of established color-harmony principles.  ColorCombo\'s four panels scroll, allowing side-by-side color comparisons.  Also text on background checker, 4096 color array, + more. FREE." href="http://www.colorcombo.com">',
#  '<a target="_blank" title="Convert MP3, WAV, AVI, JPG, GIF, and PNG to the SWF format for no buffer streaming" href="http://www.gfx2swf.com/gnome-special/">',
#  '<a target="_blank" title="Create your Web site in minutes with this easy-to-use visual tool!" href="http://www.easywebeditor.com/create_web_page_000004.htm">',
#  '<a target="_blank" title="Creating Web/CD catalogs with HyperPublish is really a snap! Not just an editor but a quick, powerful all-in-one environment for creating stunning catalogs, CDs and Web sites!" href="http://www.hyperpublish.com/create_a_catalog_000018.htm">',
#  '<a target="_blank" title="Ecobuilder is the ultimate web application that allows you to get your portal, online community, intranet, extranet or any web site project online by saving time, money and manpower. Gnomies receive $400 off the cost of the software." href="http://www.ecobuilder.com/lockergnome.cfm">',
#  '<a target="_blank" title="FirstStop WebSearch(TM) Deluxe Edition, a FREE trial version of this incredibly fast, award winning, customizable multi-search engine that has been described as the FASTEST no-nonsense meta search for the net. Now, Gnomies can save 50% when they register a copy of FirstStop WebSearch!" href="http://www.Firststopwebsearch.com/lockergnomeoffer.html">',
#  '<a target="_blank" title="Organize all your mp3 collection in seconds! You can rename mp3s quickly and easily, write tag information in batch, from file names or import it from cddb. Get your free trial now!" href="http://www.softpointer.com/tr_2.htm">',
#  '<a target="_blank" title="Share your team/project contacts, calendars, tasks, etc. in MS Oulook 2002, without a server!" href="http://outlook.4team.biz/?fr=gnome">',
#  '<a target="_blank" title="Software for filling in paper forms on your computer instead of a typewriter" href="http://www.colorpilot.com/typewriter.html">',
#  '<a target="_blank" title="Software for organizing your personal book collection. Add books quickly - no typing required! Group, filter, sort and print your database. Click for free trial version." href="http://www.collectorz.com/book?from=lockergnome">',
#  '<a target="_blank" title="You will enjoy countless hours of fun with Pretty Good Solitaire!  Play 500 solitaire card games, from classic games like Klondike, FreeCell, and Spider, to original games found nowhere else.  Enjoy lush graphics, large easy-to-read cards, statistics, and quests, a unique new way to play for points." href="http://www.goodsol.com/lockergnome.html">',
#  '<a title="Abstract  Website" target=_blank HREF="http://www.deskmod.com/?show=showcat&cat_name=abstract" >',
#  '<a title="Download A N N I H I L A T I O N" HREF="http://www.deskmod.com/?download=12328" >',
#  '<a title="Download Modular Orbb XP" HREF="http://www.deskmod.com/?download=12283" >',
#  '<a title="S2 Remotes  Website" target=_blank HREF="http://www.deskmod.com/?show=showcat&cat_name=sonique2remotes" >',
#  '<a title="View Large Image"  target=_blank HREF="http://www.deskmod.com/?state=view&skin_id=12283" >',
#  '<a title="View Large Image"  target=_blank HREF="http://www.deskmod.com/?state=view&skin_id=12328" >',
#  '<a title="Visit DeskMod" target=_blank HREF="http://www.deskmod.com" >',
#  '<b>',
#  '<body     MARGINHEIGHT="0" TOPMARGIN="0" BOTTOMMARGIN="0" bgcolor="#FFFFFF"     style="BACKGROUND-POSITION: right top; BACKGROUND-REPEAT: no-repeat" MARGINWIDTH="0" LEFTMARGIN="0" rightmargin="0" text="#26343A" alink="#008080" link="#0000FF" vlink="#26343A">',
#  '<bounce-lgmedia-2534370@sprocket.lockergnome.com>',
#  '<br>',
#  '<center>',
#  '<font size="1" face="Tahoma,Arial">',
#  '<font size="1">',
#  '<font size="2">',
#  '<font style="font-size: 10pt" face="Verdana, Tahoma, Arial" size="2">',
#  '<font style="font-size: 22pt" face="Jake Ludington, Chris Pirillo, Comic Sans MS" size="5">',
#  '<font style="font-size: 7pt" size="1" color="red" face="Verdana, Tahoma, Arial">',
#  '<font style="font-size: 8pt" face="Verdana, Tahoma, Arial" size="1">',
#  '<font style="font-size: 8pt" face="Verdana, Tahoma, Helvetica, Arial" size="1">',
#  '<form method="post" action="http://www.lockergnome.com/cgi-bin/htsearch">',
#  '<head>',
#  '<html>',
#  '<http://www.geocrawler.com/redir-sf.php3?list=spamassassin-talk>',
#  '<http://www.lockergnome.com/>',
#  '<https://example.sourceforge.net/lists/listinfo/spamassassin-talk>',
#  '<ilug-admin@linux.ie>',
#  '<ilug.linux.ie>',
#  '<ilug@linux.ie>',
#  '<img BORDER=0 SRC="http://www.deskmod.com/backend/deskmod/lncache/12283.gif" ALT="S2 Remotes by Travelian">',
#  '<img BORDER=0 SRC="http://www.deskmod.com/backend/deskmod/lncache/12328.gif" ALT="Abstract by prelude">',
#  '<img alt="DVD" border="0" width="94" height="140" src="http://images.lockergnome.com/images/dvd/tapeheads.jpg">',
#  '<img border="0" alt="Net Music Countdown" src="http://images.lockergnome.com/images/nmclogo.gif">',
#  '<img border="0" src="http://images.lockergnome.com/images/dvdgnomefull.gif">',
#  '<img border="0" src="http://images.lockergnome.com/images/dvdgnomehalf.gif">',
#  '<img height=6 src="images/blank.gif" width=1>',
#  '<img src="http://images.lockergnome.com/images/blank.gif" width="135" height="3">',
#  '<img src="http://images.lockergnome.com/images/gnomedaily.gif" width="50" height="60" hspace="5" alt="Lockergnome" border="0">',
#  '<img src="http://www.lockergnome.com/images/ads/gnomedex2002banner.gif" width="468" height="60" alt="See You at Gnomedex 2002!" border="0">',
#  '<img src="http://www.lockergnome.com/images/ads/gnomedex_vert.gif" width="125" height="400" border="0">',
#  '<img src="http://www.lockergnome.com/images/xml.gif" alt="Syndicate Today\'s Content" height="14" width="36" border="0">',
#  '<img width="125" height="94" alt="Lockergnome Webcam Image" src="http://www.lockergnome.com/images/webcam/jakecam.jpg">',
#  '<input type="hidden" name="config" value="htdig">',
#  '<input type="hidden" name="exclude" value="">',
#  '<input type="hidden" name="format" value="long">',
#  '<input type="hidden" name="method" value="and">',
#  '<input type="hidden" name="restrict" value="">',
#  '<input type="hidden" name="sort" value="score">',
#  '<input type="submit" value="Go">',
#  '<input type="text" size="9" name="words" value="">',
#  '<jm-ilug@jmason.org>',
#  '<jm-sa@jmason.org>',
#  '<jm@localhost>',
#  '<li>',
#  '<mailto:leave-lgmedia-2534370N@sprocket.lockergnome.com>',
#  '<mailto:owner-lgmedia@sprocket.lockergnome.com>',
#  '<mailto:spamassassin-talk-request@example.sourceforge.net?subject=help>',
#  '<mailto:spamassassin-talk-request@lists.sourceforge.net?subject=subscribe>',
#  '<mailto:spamassassin-talk-request@lists.sourceforge.net?subject=unsubscribe>',
#  '<mailto:spamassassin-talk@example.sourceforge.net>',
#  '<mailto:subscribe-lgmedia@sprocket.lockergnome.com>',
#  '<niall@linux.ie>',
#  '<p align="center">',
#  '<p align="right">',
#  '<p class="news">',
#  '<p class="sidebar">',
#  '<p class="title">',
#  '<p>',
#  '<qqqqqqqqqq-lg@spamassassin.taint.org>',
#  '<spamassassin-talk-admin@example.sourceforge.net>',
#  '<spamassassin-talk.example.sourceforge.net>',
#  '<spamassassin-talk@lists.sourceforge.net>',
#  '<span class="author">',
#  '<style type="text/css">',
#  '<subscriptions@lockergnome.com>',
#  '<table align="left" cellpadding="0" cellspacing="8" border="0" valign="top">',
#  '<table bgcolor="#A9C4CF" border="0" cellspacing="0" cellpadding="0" width="100%">',
#  '<table bgcolor="#A9C4CF" cellpadding="7" cellspacing="0" border="0">',
#  '<table border="0" cellspacing="5" cellpadding="0">',
#  '<table border="0">',
#  '<table cellpadding="0" cellspacing="0" border="0" width="100%" bgcolor="#B6EB8F">',
#  '<table cellpadding="0" cellspacing="0" border="0" width="100%" bgcolor="#FFEEDD">',
#  '<table cellpadding="0" cellspacing="0" border="0" width="100%">',
#  '<table cellpadding="0" cellspacing="0" border="0">',
#  '<table cellpadding="10" cellspacing="0" border="0">',
#  '<table width="100%" align="center" border="0" cellspacing="0" cellpadding="0">',
#  '<table width="100%" border="0" cellspacing="0" cellpadding="7" align="CENTER" valign="MIDDLE">',
#  '<td align="center">',
#  '<td align="left" valign="middle">',
#  '<td background="http://images.lockergnome.com/images/issue/sidebar.gif" VALIGN="top" align="left" width="145">',
#  '<td background="http://images.lockergnome.com/images/issue/top-left.gif" nowrap valign="middle" align="center" colspan="2">',
#  '<td valign="top" bgcolor="#FFFFFF">',
#  '<td>',
#  '<title>',
#  '<tr>',
#  '<ul>',
#  'AD include',
#  'AD td',
#  'ADMINISTRIVIA br',
#  'ALCANET NETFR',
#  'ALIGN center',
#  'ALT Abstract',
#  'ALT Remotes',
#  'AM brad',
#  'ASIN ref',
#  'AUDIO br',
#  'AVI BMP',
#  'AVI JPG',
#  'About Lockergnome',
#  'Abstract Website',
#  'Abstract by',
#  'Add books',
#  'Advertise With',
#  'Agent Mutt',
#  'Alcanet International',
#  'All Rights',
#  'Alphabet Speakerphone',
#  'Also text',
#  'Although this',
#  'And if',
#  'Another Day',
#  'Another alternative',
#  'Any good',
#  'Any monitor',
#  'Apple Core',
#  'Archive http',
#  'Are there',
#  'Arial CLICK',
#  'Arial Click',
#  'Arial FONT',
#  'Arial size',
#  'Arial style',
#  'Audio Commentary',
#  'Audio Show',
#  'Aug Authentication',
#  'Aug CEST',
#  'Aug Date',
#  'Aug EDT',
#  'Aug From',
#  'Aug IST',
#  'Aug On',
#  'Aug Received',
#  'Aug Return',
#  'Aug at',
#  'Authentication Warning',
#  'BACKGROUND CF',
#  'BACKGROUND IMAGE',
#  'BACKGROUND POSITION',
#  'BACKGROUND REPEAT',
#  'BANNER AD',
#  'BF for',
#  'BMP and',
#  'BOOK FOR',
#  'BORDER BOTTOM',
#  'BORDER LEFT',
#  'BORDER RIGHT',
#  'BORDER SRC',
#  'BORDER TOP',
#  'BOTTOM px',
#  'BOTTOMMARGIN bgcolor',
#  'BR nbsp',
#  'BR td',
#  'Band are',
#  'Band may',
#  'Barnstorm br',
#  'Beenthere ilug',
#  'Beenthere spamassassin',
#  'Begin Featured',
#  'Bill Fishman',
#  'Bits amp',
#  'Blog BR',
#  'Bogus Notes',
#  'Bond Foil',
#  'Bond movie',
#  'Book Collector',
#  'Book br',
#  'Boomer Stream',
#  'Boss Will',
#  'Brad the',
#  'Brand wise',
#  'Brian Stevens',
#  'Broin niall',
#  'Bruce Springsteen',
#  'Bytes br',
#  'CAn just',
#  'CD Rom',
#  'CD by',
#  'CD catalog',
#  'CD catalogs',
#  'CDROM Testing',
#  'CDs and',
#  'CENTER valign',
#  'CEST From',
#  'CF BORDER',
#  'CF border',
#  'CF cellpadding',
#  'CF scrollbar',
#  'CLICK HERE',
#  'CMT Show',
#  'COLOR FF',
#  'COLOR FONT',
#  'COLOR TEXT',
#  'COMMENT font',
#  'CRT monitor',
#  'Cafe in',
#  'Camrose Canada',
#  'Can Get',
#  'Canada br',
#  'Canada may',
#  'Canada only',
#  'Cancelled br',
#  'Captioned Widescreen',
#  'Capture TEXT',
#  'Catherine Hardwicke',
#  'Central FUNNY',
#  'Challenging song',
#  'Chat With',
#  'Check http',
#  'Chicks DMB',
#  'Chicks and',
#  'Choose between',
#  'Choosing color',
#  'Chris Book',
#  'Chris Pirillo',
#  'Chris and',
#  'Chris cannot',
#  'Click for',
#  'Click here',
#  'Closed Captioned',
#  'Collector br',
#  'Color Closed',
#  'Color Combos',
#  'ColorCombo four',
#  'Combos br',
#  'Comedy min',
#  'Comic Sans',
#  'Comment mail',
#  'Commentary Bill',
#  'Computer Power',
#  'Conor Daly',
#  'Conor it',
#  'Content Disposition',
#  'Content Type',
#  'Content height',
#  'Convert MP',
#  'Cool Internet',
#  'Core br',
#  'Corporate Release',
#  'Countdown src',
#  'Courtyard Cafe',
#  'Crazy Town',
#  'Create Web',
#  'Create your',
#  'Creating Web',
#  'Cuomo has',
#  'Cusack and',
#  'Cusack would',
#  'DBF Fri',
#  'DECORATION none',
#  'DECORATION underline',
#  'DEE EC',
#  'DMB CMT',
#  'DNS Central',
#  'DVD border',
#  'DVD br',
#  'DVD but',
#  'DVI but',
#  'DVI gives',
#  'DVI input',
#  'DVI out',
#  'DVI provides',
#  'Daily br',
#  'Daly wrote',
#  'Date Fri',
#  'Date Thu',
#  'Date Wed',
#  'Dave Matthews',
#  'Dave Neary',
#  'Day Reports',
#  'Debian id',
#  'Delivered To',
#  'Deluxe Edition',
#  'Designer ul',
#  'DeskMod font',
#  'DeskMod target',
#  'Details font',
#  'Die Another',
#  'Digital English',
#  'Digital Media',
#  'DigitalDaze Domain',
#  'Director Michael',
#  'Disposition inline',
#  'Dixie Chicks',
#  'Does anybody',
#  'Does that',
#  'Dolby Digital',
#  'Domain registered',
#  'Don worry',
#  'Download HREF',
#  'Download Modular',
#  'Download Setup',
#  'Download nbsp',
#  'Dream Theater',
#  'Dublin and',
#  'EB tr',
#  'EC px',
#  'EC scrollbar',
#  'EDT Received',
#  'ESMTP id',
#  'EVERY GEEK',
#  'Earlier in',
#  'Easy Web',
#  'Ecobuilder br',
#  'Ecobuilder is',
#  'Edition FREE',
#  'Editor br',
#  'Encoding US',
#  'End Featured',
#  'English li',
#  'Enjoy lush',
#  'Errors To',
#  'Europe wide',
#  'Executive Producer',
#  'Exim VA',
#  'Experiment br',
#  'Extreme CDROM',
#  'FAMILY Comic',
#  'FASTEST no',
#  'FE for',
#  'FEATURE br',
#  'FF TEXT',
#  'FF vlink',
#  'FFEEDD tr',
#  'FFFFFF font',
#  'FFFFFF style',
#  'FONT FAMILY',
#  'FONT SIZE',
#  'FONT WEIGHT',
#  'FOR EVERY',
#  'FREE TRIAL',
#  'FREE href',
#  'FREE https',
#  'FREE trial',
#  'FUNNY COMMENT',
#  'Fans of',
#  'Featured Skin',
#  'Feed br',
#  'Feedback General',
#  'Feedback br',
#  'FirstStop WebSearch',
#  'Firststopwebsearch com',
#  'Fishman Director',
#  'Foil br',
#  'Followup To',
#  'For Canada',
#  'For Photoshop',
#  'For further',
#  'For people',
#  'For the',
#  'Form Pilot',
#  'Formed from',
#  'FreeCell and',
#  'Fri Aug',
#  'Fri Jul',
#  'From Lockergnome',
#  'From Niall',
#  'From Stephane',
#  'From ilug',
#  'From spamassassin',
#  'Fun Sites',
#  'GA iww',
#  'GC bagend',
#  'GEEK Want',
#  'GIF Movie',
#  'GIF and',
#  'GIF animation',
#  'GIF formats',
#  'GNOMECREDITS td',
#  'GNOMEMUSIC td',
#  'GNOMESPECIALS td',
#  'Gear NT',
#  'Geekathon nbsp',
#  'General Feedback',
#  'Get Chris',
#  'Get Listed',
#  'Get full',
#  'Get new',
#  'Get your',
#  'GnomeAUDIO td',
#  'GnomeCREDITS in',
#  'GnomeDVD td',
#  'GnomeFEATURE td',
#  'GnomePLUGIN td',
#  'GnomePRODUCER td',
#  'GnomeSHOPPER nbsp',
#  'GnomeSKIN td',
#  'GnomeTomes com',
#  'GnomeWALLPAPER td',
#  'Gnomedex border',
#  'Gnomies br',
#  'Gnomies can',
#  'Gnomies receive',
#  'Go BR',
#  'Goes to',
#  'Good Solitaire',
#  'Group filter',
#  'Group ilug',
#  'HERE TO',
#  'HERE to',
#  'HREF http',
#  'HTML mail',
#  'Hardwicke Production',
#  'Have you',
#  'Hear the',
#  'Help mailto',
#  'Helvetica Arial',
#  'Here Question',
#  'Here br',
#  'Hi have',
#  'High Tech',
#  'Hobbiton cod',
#  'Hollywood stereotypes',
#  'Host Lockergnome',
#  'Host nw',
#  'Hot For',
#  'However if',
#  'HyperPublish is',
#  'ILUG LCD',
#  'ILUG ilug',
#  'IMAGE url',
#  'IMAP fetchmail',
#  'ISSN All',
#  'IST Date',
#  'IST Received',
#  'Id GA',
#  'Id GC',
#  'Id Irish',
#  'Id LISTMANAGERSQL',
#  'Id Talk',
#  'If geek',
#  'If you',
#  'Iiyama lot',
#  'Image src',
#  'Image target',
#  'In Reply',
#  'In Your',
#  'Interface Date',
#  'International Internet',
#  'Internet Services',
#  'Internet Tips',
#  'Internet browsing',
#  'Internet connections',
#  'Irish Linux',
#  'Issues br',
#  'It Milter',
#  'It both',
#  'It for',
#  'It has',
#  'It just',
#  'It seems',
#  'Iy Wed',
#  'JPG AVI',
#  'JPG GIF',
#  'Jake Blog',
#  'Jake Ludington',
#  'Jd for',
#  'Jeff Orr',
#  'Job Search',
#  'Joe Satriani',
#  'John Cusack',
#  'Jul Mailer',
#  'Jul Subject',
#  'Just go',
#  'JvJ for',
#  'King of',
#  'Kiss style',
#  'Kleptomania br',
#  'Klondike FreeCell',
#  'Know Tech',
#  'Kyocera QCP',
#  'LA area',
#  'LCD as',
#  'LCD monitors',
#  'LEFT DEE',
#  'LEFTMARGIN rightmargin',
#  'LHsTWb for',
#  'LHvHZ for',
#  'LISTMANAGERSQL qqqqqqqqqq',
#  'LLC ISSN',
#  'LOCKERGNOME td',
#  'LPs to',
#  'Large Image',
#  'Latest Apple',
#  'Latest Audio',
#  'Latest Bits',
#  'Latest Digital',
#  'Latest Penguin',
#  'Latest Tech',
#  'Latest Web',
#  'Latest Windows',
#  'Lentz Alcanet',
#  'Lentz Stephane',
#  'Lentz ansf',
#  'Link To',
#  'Linux Users',
#  'Liquid Tension',
#  'List Archive',
#  'List Help',
#  'List Host',
#  'List Id',
#  'List Owner',
#  'List Post',
#  'List Subscribe',
#  'List Unsubscribe',
#  'List maintainer',
#  'ListManager Web',
#  'Listed Here',
#  'Lockergnome Digital',
#  'Lockergnome LLC',
#  'Lockergnome Site',
#  'Lockergnome Webcam',
#  'Lockergnome border',
#  'Lockergnome br',
#  'Lockergnome http',
#  'Lockergnome old',
#  'Lori and',
#  'Ludington Chris',
#  'Ludington nbsp',
#  'MARGINHEIGHT TOPMARGIN',
#  'MARGINWIDTH LEFTMARGIN',
#  'MIDDLE tr',
#  'MIME Version',
#  'MP WAV',
#  'MS Helvetica',
#  'MS Oulook',
#  'MS Trebuchet',
#  'MS size',
#  'Mac OS',
#  'Madonna Plays',
#  'Madonna will',
#  'Madshrimps Extreme',
#  'Mail Followup',
#  'Mailbox Too',
#  'Mailer Bogus',
#  'Mailer ListManager',
#  'Mailman Version',
#  'Manage Your',
#  'Matthews Band',
#  'Maybe you',
#  'Media Alphabet',
#  'Media Comment',
#  'Media br',
#  'Media subscriptions',
#  'Media title',
#  'MediaREPORT td',
#  'Message Id',
#  'Michael Nesmith',
#  'Michael br',
#  'Microsoft Office',
#  'Mikrosoft Xchange',
#  'Milter program',
#  'Mimedefang it',
#  'Modular Orbb',
#  'Monica which',
#  'More Options',
#  'Movie Gear',
#  'Much Sympathy',
#  'Music Countdown',
#  'Music is',
#  'Must Know',
#  'Mutt Sender',
#  'My CRT',
#  'My configuration',
#  'My second',
#  'NETFR with',
#  'NEWS table',
#  'NMC eCharters',
#  'NT XP',
#  'Neary Any',
#  'Needless to',
#  'Nesmith Executive',
#  'Net Music',
#  'Niall Broin',
#  'Niall Irish',
#  'Nickelback Too',
#  'Nickelback fans',
#  'No need',
#  'Not Much',
#  'Not just',
#  'Not surprising',
#  'Notes Corporate',
#  'Nothing really',
#  'Now Gnomies',
#  'Now You',
#  'Now all',
#  'Now br',
#  'OS go',
#  'OS tips',
#  'OSDN Tired',
#  'Of course',
#  'Of interest',
#  'Office Tips',
#  'On Fri',
#  'On Wed',
#  'Opinion br',
#  'Options br',
#  'Orbb XP',
#  'Organize all',
#  'Original Date',
#  'Orr class',
#  'Oulook without',
#  'Our Privacy',
#  'Our Tips',
#  'Our Web',
#  'Our XML',
#  'Owner mailto',
#  'PC Productivity',
#  'PC how',
#  'PC time',
#  'PDF only',
#  'PLUGIN br',
#  'PM Conor',
#  'PM nbsp',
#  'PNG to',
#  'POSITION right',
#  'PRODUCER br',
#  'PSD JPG',
#  'Palm devices',
#  'Palm powered',
#  'Palm with',
#  'Past Issues',
#  'Path bounce',
#  'Path ilug',
#  'Path spamassassin',
#  'Penguin Shell',
#  'PenguinCORE br',
#  'PenguinTWEAKS br',
#  'Photoshop No',
#  'Photoshop class',
#  'Pilot br',
#  'Pirillo Comic',
#  'Pirillo In',
#  'Pirillo at',
#  'Play solitaire',
#  'Plays Bond',
#  'Please read',
#  'Policy br',
#  'Poor Richard',
#  'Pop claim',
#  'Post mailto',
#  'Posted on',
#  'Postfix from',
#  'Postfix with',
#  'Power User',
#  'Precedence bulk',
#  'Pretty Good',
#  'Privacy Policy',
#  'Producer Catherine',
#  'Production Designer',
#  'Productivity Tips',
#  'Publishing by',
#  'QCP Palm',
#  'Question is',
#  'Question which',
#  'REPEAT no',
#  'RIGHT px',
#  'RSS Feed',
#  'Re ILUG',
#  'Re SAtalk',
#  'Read Past',
#  'Received by',
#  'Received from',
#  'Recommend Us',
#  'References Hobbiton',
#  'References camel',
#  'Region Encoding',
#  'Release Virus',
#  'Remotes Website',
#  'Remotes by',
#  'Rename br',
#  'Rene Courtyard',
#  'Reply To',
#  'Reports say',
#  'Reserved Please',
#  'Return Path',
#  'Reviewer Tilt',
#  'Richard mail',
#  'Richard series',
#  'Rights Reserved',
#  'Rising and',
#  'Rivers Cuomo',
#  'Robbins make',
#  'Robbins nor',
#  'Rom drive',
#  'SA using',
#  'SAtalk spamc',
#  'SIZE pt',
#  'SKIN br',
#  'SL Stephane',
#  'SMTP id',
#  'SPAMD protocol',
#  'SRC http',
#  'SWF format',
#  'Sans MS',
#  'Santa Monica',
#  'Satriani and',
#  'Say the',
#  'Scanned by',
#  'Search Past',
#  'Search br',
#  'See You',
#  'Sender bounce',
#  'Sender ilug',
#  'Sender spamassassin',
#  'Sendmail with',
#  'Service Our',
#  'Services This',
#  'Set your',
#  'Setup br',
#  'Share your',
#  'Shell br',
#  'Show BR',
#  'Show Cancelled',
#  'Singer Goes',
#  'Site Feedback',
#  'Sites br',
#  'Skin ADMINISTRIVIA',
#  'Skin AUDIO',
#  'Skin span',
#  'Software for',
#  'Solitaire Play',
#  'Solitaire br',
#  'Sony Music',
#  'Sound Dolby',
#  'SpamAssassin for',
#  'SpamAssassin spamassassin',
#  'Spamassassin talk',
#  'Speakerphone To',
#  'Specialist br',
#  'Spider to',
#  'Springsteen and',
#  'Stephane Lentz',
#  'Steve Vai',
#  'Stevens already',
#  'Stream Now',
#  'Street Band',
#  'Subject Lockergnome',
#  'Subject Re',
#  'Submit Your',
#  'Subscribe https',
#  'Subscribe mailto',
#  'Sympathy for',
#  'Syndicate Our',
#  'Syndicate Today',
#  'TEXT ALIGN',
#  'TEXT DECORATION',
#  'TEXT seen',
#  'TM Deluxe',
#  'TO ZOOM',
#  'TOP BANNER',
#  'TOP DEE',
#  'TOPMARGIN BOTTOMMARGIN',
#  'TRIAL issues',
#  'TV were',
#  'Tag amp',
#  'Tahoma Arial',
#  'Tahoma Helvetica',
#  'Talk about',
#  'Tapeheads br',
#  'Tech Job',
#  'Tech Sites',
#  'Tech Specialist',
#  'Tech Terms',
#  'Tension Experiment',
#  'Terms br',
#  'Terms of',
#  'Testing class',
#  'Thanks Brad',
#  'Thanks again',
#  'That said',
#  'The Boss',
#  'The GnomeSHOPPER',
#  'The King',
#  'The Rising',
#  'The Webcams',
#  'The check',
#  'The majority',
#  'The movie',
#  'The much',
#  'The product',
#  'The software',
#  'Theater the',
#  'There are',
#  'They don',
#  'This sf',
#  'Thu Aug',
#  'Thu Jul',
#  'Tilt img',
#  'Tim Robbins',
#  'Time br',
#  'Time free',
#  'Tips br',
#  'Tired of',
#  'To Hobbiton',
#  'To ILUG',
#  'To Lockergnome',
#  'To Niall',
#  'To Stephane',
#  'To camel',
#  'To ilug',
#  'To leave',
#  'To qqqqqqqqqq',
#  'To resubscribe',
#  'To spamassassin',
#  'To unsubscribe',
#  'To yyyy',
#  'Today Content',
#  'Too Computer',
#  'Too Hot',
#  'Top Fun',
#  'Top PenguinCORE',
#  'Top PenguinTWEAKS',
#  'Top Tech',
#  'Top Useful',
#  'Town Weezer',
#  'Town br',
#  'Travelian center',
#  'Travelian span',
#  'Trebuchet MS',
#  'Try Say',
#  'Tue Aug',
#  'Two out',
#  'Type text',
#  'UAA Fri',
#  'UAA for',
#  'URGH thinking',
#  'URL http',
#  'US and',
#  'Unearthed by',
#  'Universal titles',
#  'Unsubscribe https',
#  'Unsubscribe mailto',
#  'Us br',
#  'Useful Sites',
#  'User Agent',
#  'User br',
#  'User magazine',
#  'Users Group',
#  'VA mm',
#  'VALIGN top',
#  'VGA because',
#  'VGA connectors',
#  'Vai are',
#  'Verdana Tahoma',
#  'Verizon at',
#  'Version Content',
#  'Version Precedence',
#  'Version sf',
#  'View Large',
#  'View More',
#  'Vinyl LPs',
#  'Virus Scanned',
#  'Visit DeskMod',
#  'Visualize Color',
#  'WALLPAPER br',
#  'WAV AVI',
#  'WEIGHT bold',
#  'WEIGHT normal',
#  'WHERE was',
#  'WMV capable',
#  'Wallpampered NT',
#  'Want to',
#  'Warning lugh',
#  'Watch The',
#  'Watch as',
#  'Web CD',
#  'Web Editor',
#  'Web Interface',
#  'Web Weekly',
#  'Web design',
#  'Web does',
#  'Web for',
#  'Web site',
#  'Web sites',
#  'WebSearch TM',
#  'WebSearch br',
#  'WebSearch href',
#  'Webcam Image',
#  'Webcams br',
#  'Website target',
#  'Wed Aug',
#  'Weekly br',
#  'Weezer Singer',
#  'Weezer front',
#  'What are',
#  'What with',
#  'Widescreen li',
#  'Will Barnstorm',
#  'Windows Daily',
#  'Windows Tips',
#  'Windows XP',
#  'With Gnomies',
#  'With Us',
#  'With the',
#  'Workgroup br',
#  'XFree setup',
#  'XFree to',
#  'XML RSS',
#  'XP HREF',
#  'XP Tips',
#  'XP br',
#  'XP class',
#  'XP for',
#  'Xchange from',
#  'Yes music',
#  'You Can',
#  'You at',
#  'You can',
#  'You will',
#  'Your Mailbox',
#  'Your Opinion',
#  'Your Workgroup',
#  'Your subscribed',
#  'ZOOM font',
#  'Zoom nbsp',
#  '_',
#  '_______________________________________________',
#  'ability to',
#  'about SpamAssassin',
#  'about an',
#  'about anything',
#  ...]

# %% [markdown]
# <p><b>The pipelines for this Classifier</b></p>
# <ul>
#     <li>Selects the content of each mail</li>
#     <li>Uses CountVectorizer, distinguishing between uppercase and lowercase words, and uses the newly created analyzer nGramAnalyzer or nGramAnalyzer_only_words.</li>
#     <li>Performs Logistic Regression </li>
# </ul>
# <p>There are two pipelines. The first one takes into account html tags, money and underscores besides the bigrams, while the other one only focuses on bigrams</p>

# %%
pipeline3 = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", CountVectorizer(lowercase=False, analyzer=nGramAnalyzer)),
    ("estimator", LogisticRegression())
])
pipeline3_only_bigrams = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", CountVectorizer(lowercase=False, analyzer=nGramAnalyzer_only_words)),
    ("estimator", LogisticRegression())
])

# %% [markdown]
# <b>Accuracy - in case of nGramAnalyzer</b>

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline3, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.97792148908244836

# %% [markdown]
# <b>Accuracy - in case of nGramAnalyzer_only_words</b>

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline3_only_bigrams, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.97895716501610797

# %% [markdown]
# <h1> 5.4 Classifier #4</h1>
# <font size="4">Uses <b>TfidfVectorizer</b>(stop_words, lowercase and tokenizer) and <b>SGDClassifier</b>.</font>
# <p>Another estimator we can use is the Stochastic Gradient Descent Classifier. <info about it></p>
# <p>The pipeline for this classifier:</p>
# <ul>
#     <li>Select the content of the mails using DataFrameSelector</li>
#     <li>TFIDF is used, because SGDClassifier works better if the features are scaled. In case of CountVectorizer the features will represent the frequency of a word, which is a positive integer(not scaled). In case of Tfidf the values of the features are in the range of 0 to 1. In case of CountVectorizer, without scaling the features, the accuracy was lower.</li>
#     <li>SGDClassifier: it will stop after max_iter iterations, or when the difference in the loss is smaller than the tolerance tol. The learning-rate is left with the default value.</li>

# %%
pipeline4 = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", TfidfVectorizer(stop_words='english', 
                                   lowercase=False,
                                   tokenizer=tokenize)),
    ("estimator", SGDClassifier(max_iter=500, tol=1e-4))
])

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline4, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.98206299964204735

# %%
y_predicted_4 = cross_val_predict(pipeline4, mails, y_encoded, cv=10)
confusion_matrix(y_encoded, y_predicted_4)
# Out:
# array([[1630,   20],
#        [  30, 1218]])

# %% [markdown]
# <h1> 5.5 Classifier #5</h1>
# <font size="4">Uses <b>TfidfVectorizer, Bigrams</b> and <b>SGDClassifier</b>.</font>

# %%
pipeline5 = Pipeline([
    ("selector", DataFrameSelector("content")),
    ("vectorizer", TfidfVectorizer(lowercase=False, analyzer=nGramAnalyzer_only_words)),
    ("estimator", SGDClassifier(max_iter=200, tol=1e-4))
])

# %%
kf = StratifiedKFold(n_splits = 10)
np.mean(cross_val_score(pipeline5, mails, y_encoded, scoring="accuracy", cv=kf))
# Out:
# 0.98171817205584055

# %%
y_predicted_5 = cross_val_predict(pipeline5, mails, y_encoded, cv=10)
confusion_matrix(y_encoded, y_predicted_5)
# Out:
# array([[1623,   27],
#        [  28, 1220]])

# %% [markdown]
# <h1> 6 References</h1>

# %% [markdown]
# <p>[1] Reading all the text files from directory, stackoverflow.com: https://stackoverflow.com/questions/37534141/reading-all-the-text-files-from-directory</p>
# <p>[2] Python Regular Expressions tutorial, tutorialspoint.com: https://www.tutorialspoint.com/python/python_reg_expressions.htm</p>
# <p>[3] CountVectorizer, scikit-learn.org: http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html</p>
# <p>[4] TfidfVectorizer, scikit-learn.org: http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html</p>
# <p>[5] Stochastic Gradient Descent Classifier, scikit-learn.org: http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html</p>
# <p>[6] 4.2.3.3. Common Vectorizer usage, scikit-learn.org: http://scikit-learn.org/stable/modules/feature_extraction.html</p>
# <p>[7] pandas.DataFrame, pandas.pydata.org: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html </p>
